# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.16.1)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.32)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.38.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (68.1.2)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2023.11.17)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)

# %%
import wandb

# %%
wandb.login(key="509e34d1036abaa2034ee59d3dae5b090f6514ab")
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# ! pip install -U accelerate
# ! pip install -U transformers

# %%
# !pip install trl pytorch-lightning
# Out:
# Collecting trl
#   Obtaining dependency information for trl from https://files.pythonhosted.org/packages/0d/44/c406c3cf5981bddb16ff72acb5ca235888db4073d868cf51bd143bef3aad/trl-0.7.4-py3-none-any.whl.metadata
#   Downloading trl-0.7.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: torch>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from trl) (2.0.0)
# Requirement already satisfied: transformers>=4.18.0 in /opt/conda/lib/python3.10/site-packages (from trl) (4.35.2)
# Requirement already satisfied: numpy>=1.18.2 in /opt/conda/lib/python3.10/site-packages (from trl) (1.24.3)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (from trl) (0.25.0)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from trl) (2.1.0)
# Collecting tyro>=0.5.11 (from trl)
#   Obtaining dependency information for tyro>=0.5.11 from https://files.pythonhosted.org/packages/c5/11/abdf67467d06713b431618732a43f82d1b1f02120107b05a789afbcdf54d/tyro-0.6.0-py3-none-any.whl.metadata
#   Downloading tyro-0.6.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (2023.12.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (1.2.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.5.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.10.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.8.0->pytorch-lightning) (68.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pytorch-lightning) (3.0.9)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.18.0->trl) (0.19.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.18.0->trl) (2023.8.8)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.18.0->trl) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.18.0->trl) (0.4.1)
# Requirement already satisfied: docstring-parser>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (0.15)
# Requirement already satisfied: rich>=11.1.0 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (13.5.2)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Obtaining dependency information for shtab>=1.5.6 from https://files.pythonhosted.org/packages/40/ad/7227da64498eaa7abecee4311008f70869e156014b3270cec36e2e70cd31/shtab-1.6.5-py3-none-any.whl.metadata
#   Downloading shtab-1.6.5-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate->trl) (5.9.3)
# Requirement already satisfied: pyarrow>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (11.0.0)
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (0.3.7)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (2.0.3)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (0.70.15)
# Requirement already satisfied: responses<0.19 in /opt/conda/lib/python3.10/site-packages (from datasets->trl) (0.18.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.4.0->trl) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->trl) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl) (1.16.0)
# Downloading trl-0.7.4-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 5.6 MB/s eta 0:00:00
# Downloading tyro-0.6.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 11.1 MB/s eta 0:00:00
# Downloading shtab-1.6.5-py3-none-any.whl (13 kB)
# Installing collected packages: shtab, tyro, trl
# Successfully installed shtab-1.6.5 trl-0.7.4 tyro-0.6.0

# %%
import torch
from torch import nn
import numpy as np
from datasets import Dataset
from transformers import GPT2LMHeadModel, GPT2Tokenizer, pipeline, TrainingArguments
from transformers import pipeline
from trl import DPOTrainer as DPOTrainer_init
from pytorch_lightning import seed_everything
import pytorch_lightning as pl
import torch.nn.functional as F
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Any, Callable, Dict, List, Literal, Optional, Tuple, Union
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(

# %%
seed_everything(42, workers=True)
# Out:
# 42

# %%
TRAIN_HINGE = True
TRAIN_SIGMOID = True

# %% [markdown]
# # SFT model

# %%
model_name = "lvwerra/gpt2-imdb"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
starting_phrases = [
    "This movie is",
    "The acting was",
    "I think that this film",
    "The plot was",
]

number_of_samples = 10000
sequences_for_prompt = number_of_samples // len(starting_phrases)
batch_size = 200
max_length = 100
top_k = 50

# %%
def generate_texts(model, sequences_for_prompt=sequences_for_prompt, starting_phrases=starting_phrases):
    generated_texts = []
    for phrase in starting_phrases:
        encoded_input = tokenizer(phrase, return_tensors="pt").to(device)

        n_left_sequences = sequences_for_prompt
        cur_phrase_sequences = []

        while n_left_sequences > 0:
            generated_text = model.generate(**encoded_input,
                                            max_length=max_length,
                                            num_return_sequences=min(n_left_sequences, batch_size),
                                            pad_token_id=tokenizer.eos_token_id,#add top_k
                                            do_sample=True
                                            )
            n_left_sequences -= batch_size
            cur_phrase_sequences.extend([tokenizer.decode(generated_text[i], skip_special_tokens=True) for i in range(len(generated_text))])
            torch.cuda.empty_cache()

        generated_texts.append(cur_phrase_sequences)
    return generated_texts

# %%
generated_texts = generate_texts(model)

print(f"your dataset has {len(generated_texts) * batch_size} samples")
print("Generated texts:")

for x in generated_texts[0][:10]:
    print(x)
# Out:
# your dataset has 800 samples
# Generated texts:
# This movie is so bad it shouldn't even be listed.
# This movie is about a woman who is getting murdered, her family is going to take care of her when he dies, she decides to join a group who are all trying to take revenge on his past so she can leave. The idea of all the young women on their own and taking revenge is really fun, it makes for a funny and touching film. There is a lot of character development that are very cool to watch, I was really surprised to find a lot of girls in the cast and I
# This movie is a great comedy noir. It is funny but that was never going to be a problem.<br /><br />The story is very interesting. I don't agree with an author who writes about this in "Top Secret." Just because his book is not published on the American Film Academy standards did not make him a writer for this type of movie. I would say this movie is a great movie in it's own right, it is good entertainment but that is not its fault.<
# This movie is nothing like this: The movie takes place in Paris, at an important place, where French people are being killed, and one wonders why Parisites don't like the French, as they do elsewhere. The scene in the bar scene has to be my favorite moment in the movie as well, because I can say that Paris is definitely one of the most important capitals for the French. A romantic picture just won't do!
# This movie is the first movie to focus on the lives the boys at school experience in life. If you are familiar with the old adage "don't call yourself a movie star", you will understand that I have no problem with this. However, the fact is that I like the movie because it shows that there is something truly exceptional about everyone in this movie. I really like this movie because it is as uplifting as The Nutcracker (which was originally broadcast on TV). I think that
# This movie is really, really bad. It's awful. It's a really, really, really bad movie. It's a really, really bad movie. If you had to pick one movie for your film school to watch, it was: "The Muppet Movie" by Mark Wahlberg. "The Wizard of Oz" by J.M. DeMatteis is a classic example. It's as bad as it gets. I can almost guarantee that if you're looking to rent
# This movie is about the journey of two men stranded on a desert planet called Eden. It is a great and beautiful movie. What is important to realize is: that for this movie, there is a journey that would be impossible for the next woman. We have two girls and one girl of our respective ages. This film, however, was extremely boring and boring at times. The plot was very interesting, which is the reason why I gave it 7 out of 10 stars. <br /><br
# This movie is absolutely the best movie I have seen in a long time.<br /><br />I don't see a single reason why anyone would rather watch something that has been made for television without any sort of originality and that is something that is absolutely unoriginal. However, in general, when people give a movie a 9 out of 10 because it has nothing to offer, to a point where it becomes less and less a good movie about racism, slavery, and colonialism, they are doing
# This movie is the first-ever feature length version I've seen of this film. This version of the film would be one big letdown for both myself and my friends. The story is so boring it's confusing but a good movie nonetheless. For those who really love Sci-Fi, this is a must for everyone, or anybody that's not a fan of the genre. Highly recommended.
# This movie is an insult to the spirit of Disney Movies... a movie that actually fails in many areas. The only thing to the plot/direction is the music. The first story in this movie actually works... there is only one character, and this is one of the few that isn't an animal. As to the plot...the film starts off looking like this: the animals are very shy and are shy-loving. Next the movie becomes full of ridiculous things like 'I have no idea where

# %% [markdown]
# # Reward model

# %%
from transformers import pipeline
reward_model_name = "lvwerra/distilbert-imdb"
reward_model = pipeline("text-classification", reward_model_name, device=device)
# Out:
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def score_texts(reward_model, generated_texts):
    rewards = []
    for batch in generated_texts:
        out = reward_model(batch, batch_size=batch_size)
        binary_scores = list(map(lambda x: x["score"] if x["label"] == "POSITIVE" else 1 - x["score"], out))
        rewards.append(np.array(binary_scores))
    return rewards

# %%
rewards = score_texts(reward_model, generated_texts)
print("text -> score")
for text, score in zip(generated_texts[0][:10], rewards[0][:10]):
    print(text[:100] + "...", score)
# Out:
# text -> score
# This movie is so bad it shouldn't even be listed.... 0.0041390061378479
# This movie is about a woman who is getting murdered, her family is going to take care of her when he... 0.9942613840103149
# This movie is a great comedy noir. It is funny but that was never going to be a problem.<br /><br />... 0.9524638056755066
# This movie is nothing like this: The movie takes place in Paris, at an important place, where French... 0.3992178440093994
# This movie is the first movie to focus on the lives the boys at school experience in life. If you ar... 0.993016242980957
# This movie is really, really bad. It's awful. It's a really, really, really bad movie. It's a really... 0.005022227764129639
# This movie is about the journey of two men stranded on a desert planet called Eden. It is a great an... 0.12854361534118652
# This movie is absolutely the best movie I have seen in a long time.<br /><br />I don't see a single ... 0.9196087718009949
# This movie is the first-ever feature length version I've seen of this film. This version of the film... 0.9769953489303589
# This movie is an insult to the spirit of Disney Movies... a movie that actually fails in many areas.... 0.007604122161865234

# %% [markdown]
# # Creating dpo dataset

# %%
def create_dataset(num_samples, generated_texts, rewards):
    dataset = {
        "prompt": [],
        "chosen": [],
        "rejected": []
        }
    for i in range(num_samples):
        idx = np.random.randint(0, len(starting_phrases))

        first_example = np.random.randint(0, len(generated_texts[idx]))
        second_example = first_example

        while second_example == first_example:
            second_example = np.random.randint(0, len(generated_texts[idx]))

        first_score = rewards[idx][first_example]
        second_score = rewards[idx][second_example]

        if first_score > second_score:
            chosen = generated_texts[idx][first_example]
            rejected = generated_texts[idx][second_example]
        else:
            chosen = generated_texts[idx][second_example]
            rejected = generated_texts[idx][first_example]

        dataset["prompt"].append(starting_phrases[idx])
        dataset["chosen"].append(chosen)
        dataset["rejected"].append(rejected)
    dataset = Dataset.from_dict(dataset)
    return dataset

# %%
if TRAIN_HINGE or TRAIN_SIGMOID:
    num_samples = 64_000 # in paper they have 64k examples
    train_dataset = create_dataset(num_samples, generated_texts, rewards)

# %%
if TRAIN_HINGE or TRAIN_SIGMOID:
    val_texts = generate_texts(model, int(sequences_for_prompt * 0.2))
    val_rewards = score_texts(reward_model, val_texts)
    val_dataset = create_dataset(int(num_samples * 0.2), val_texts, val_rewards)

# %% [markdown]
# # Initializing dpo trainer

# %% [markdown]
# \begin{equation}
# f = \frac{u^{1-\alpha} - (1 - \alpha)u - \alpha}{\alpha(\alpha - 1)}
# \end{equation}

# %% [markdown]
# \begin{equation}
# f' = \frac{1 - u^{-\alpha}}{\alpha}
# \end{equation}

# %%
def f_kl(chosen_log_probs, ref_chosen_log_probs, alpha=0.5):
    u = torch.exp(chosen_log_probs - ref_chosen_log_probs)
    u = torch.clamp(u, min=1e-12) 
    return (1 - u ** (-alpha)) / alpha

# %%
class DPOTrainer(DPOTrainer_init):
    def __init__(self, *args, **kwargs):
        super(DPOTrainer, self).__init__(*args, **kwargs)
        self.beta = 0.1
        self.f_kl_alpha = 0.5
        self.label_smoothing=0
    def dpo_loss(
        self,
        policy_chosen_logps: torch.FloatTensor,
        policy_rejected_logps: torch.FloatTensor,
        reference_chosen_logps: torch.FloatTensor,
        reference_rejected_logps: torch.FloatTensor,
        reference_free: bool = False,
    ) -> Tuple[torch.FloatTensor, torch.FloatTensor, torch.FloatTensor]:
        """Compute the DPO loss for a batch of policy and reference model log probabilities.

        Args:
            policy_chosen_logps: Log probabilities of the policy model for the chosen responses. Shape: (batch_size,)
            policy_rejected_logps: Log probabilities of the policy model for the rejected responses. Shape: (batch_size,)
            reference_chosen_logps: Log probabilities of the reference model for the chosen responses. Shape: (batch_size,)
            reference_rejected_logps: Log probabilities of the reference model for the rejected responses. Shape: (batch_size,)
            reference_free: If True, we ignore the _provided_ reference model and implicitly use a reference model that assigns equal probability to all responses.

        Returns:
            A tuple of three tensors: (losses, chosen_rewards, rejected_rewards).
            The losses tensor contains the DPO loss for each example in the batch.
            The chosen_rewards and rejected_rewards tensors contain the rewards for the chosen and rejected responses, respectively.
        """
        # changed code starts here
        f1 = f_kl(policy_chosen_logps, reference_chosen_logps, self.f_kl_alpha)
        f2 = f_kl(policy_rejected_logps, reference_rejected_logps, self.f_kl_alpha)

        logits = f1 - f2
        # ends here
        if self.loss_type == "sigmoid":
            losses = (
                -F.logsigmoid(self.beta * logits) * (1 - self.label_smoothing)
                - F.logsigmoid(-self.beta * logits) * self.label_smoothing
            )
        elif self.loss_type == "hinge":
            losses = torch.relu(1 - self.beta * logits)
        elif self.loss_type == "ipo":
            # eqn (17) of the paper where beta is the regularization parameter for the IPO loss, denoted by tau in the paper.
            losses = (logits - 1 / (2 * self.beta)) ** 2
        elif self.loss_type == "kto":
            # eqn (7) of the HALOs paper
            chosen_KL = (policy_chosen_logps - reference_chosen_logps).mean().clamp(min=0)
            rejected_KL = (policy_rejected_logps - reference_rejected_logps).mean().clamp(min=0)

            chosen_logratios = policy_chosen_logps - reference_chosen_logps
            rejected_logratios = policy_rejected_logps - reference_rejected_logps
            # As described in the KTO report, the KL term for chosen (rejected) is estimated using the rejected (chosen) half.
            losses = torch.cat(
                (
                    1 - F.sigmoid(self.beta * (chosen_logratios - rejected_KL)),
                    1 - F.sigmoid(self.beta * (chosen_KL - rejected_logratios)),
                ),
                0,
            )
        else:
            raise ValueError(
                f"Unknown loss type: {self.loss_type}. Should be one of ['sigmoid', 'hinge', 'ipo', 'kto']"
            )

        chosen_rewards = self.beta * (policy_chosen_logps - reference_chosen_logps).detach()
        rejected_rewards = self.beta * (policy_rejected_logps - reference_rejected_logps).detach()
        return losses, chosen_rewards, rejected_rewards

# %%
def flatten(l):
    return [item for sublist in l for item in sublist]

# %%
from scipy.stats import entropy
from collections import defaultdict
def token_entropy(generations, tokenizer):
    stats = defaultdict(int)
    num_tokens = 0
    for example in generations:
        tokens = tokenizer.encode(example)
        for t in tokens:
            if t == tokenizer.pad_token_id:
                continue
            stats[t] += 1
            num_tokens += 1
    for k in stats.keys():
        stats[k] /= num_tokens
    return entropy(list(stats.values()))

# %%
init_entropy = token_entropy(flatten(generated_texts), tokenizer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 init_entropy = token_entropy(flatten(generated_texts), tokenizer)
# ----> 2 hinge_model_entropy = token_entropy(flatten(hinge_model_texts), tokenizer)
#
# NameError: name 'hinge_model_texts' is not defined

# %% [markdown]
# # Sigmoid loss

# %%
if TRAIN_SIGMOID:
    sigmoid_model = GPT2LMHeadModel.from_pretrained(model_name)
    model_ref = GPT2LMHeadModel.from_pretrained(model_name) # don't need it?

# %%
if TRAIN_SIGMOID:
    training_args = TrainingArguments(
        output_dir='./results/sigmoid',
        num_train_epochs=1,
        per_device_train_batch_size=16,
        learning_rate=1e-5,
        eval_steps=600,
        save_strategy="steps",
        evaluation_strategy="steps",
        logging_steps=40
    )

# %%
if TRAIN_SIGMOID:
    save_path = 'sigmoid_model'
    # !mkdir {save_path} 
    model.save_pretrained(save_path)
    # !zip -r model.zip {save_path}
# Out:
#   adding: sigmoid_model/ (stored 0%)
#   adding: sigmoid_model/generation_config.json (deflated 24%)
#   adding: sigmoid_model/config.json (deflated 51%)
#   adding: sigmoid_model/model.safetensors (deflated 7%)

# %%
if TRAIN_SIGMOID:
    dpo_trainer = DPOTrainer(
        sigmoid_model,
        model_ref,
        beta=0.1,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        tokenizer=tokenizer,
        loss_type="sigmoid",
        max_length=max_length,
        max_prompt_length=max(list(map(lambda x: len(x), starting_phrases))),
    )
# Out:
# /opt/conda/lib/python3.10/site-packages/trl/trainer/dpo_trainer.py:291: UserWarning: When using DPODataCollatorWithPadding, you should set `remove_unused_columns=False` in your TrainingArguments we have set it for you, but you should do it yourself in the future.
#   warnings.warn(

# %%
if TRAIN_SIGMOID:
    dpo_trainer.train()
# Out:
# tensor(0.6931, device='cuda:0', grad_fn=<MeanBackward0>)
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 03:32, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# tensor(0.6891, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6794, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6621, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6812, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6704, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6488, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6286, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6670, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5539, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(2.2425, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.1678, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4343, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(4.7074, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4805, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4286, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5238, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3815, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7803, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7600, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7675, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3532, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.4117, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4365, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2504, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8534, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7008, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4949, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8965, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7601, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5595, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5051, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4136, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4457, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4375, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3264, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5265, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5540, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4497, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.2749, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.1223, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7157, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.9698, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3728, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3750, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4391, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6443, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3790, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.1304, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8117, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7103, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7322, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4704, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4043, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5218, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8605, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8048, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5359, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7701, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5146, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4632, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6347, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7063, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5381, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4945, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5029, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(8.7822, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5152, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7026, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7806, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5741, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5097, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5691, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5066, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5056, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5638, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4046, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4274, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5229, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.4527, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3455, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4482, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3802, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3595, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5897, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4073, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5962, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2782, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.1757, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4766, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7490, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5038, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3958, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6890, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8519, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.8987, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2601, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7837, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5138, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5948, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5344, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8030, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3543, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4201, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3198, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2868, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.9500, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.5175, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5330, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3239, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3500, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6976, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2585, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.0042, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5108, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2813, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4506, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.5535, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.2104, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2875, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3360, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6454, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2211, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6574, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.0202, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.6120, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.4406, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5451, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6589, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4888, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2875, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8543, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4648, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6659, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7477, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4735, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(2.2370, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5681, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4369, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2813, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(3.3497, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8939, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7099, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7084, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4164, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5276, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4204, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8651, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.0865, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4838, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4095, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6484, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4775, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5442, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5090, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6025, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5933, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7599, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4298, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3512, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5395, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5334, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6094, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3472, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4986, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3101, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2823, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5681, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4170, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4850, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4059, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3661, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3702, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3716, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3801, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3634, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.2105, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4451, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3580, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3020, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6009, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.3210, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2659, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4839, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.9070, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2271, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8069, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5199, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.9473, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.6564, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3430, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4928, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3620, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4061, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4566, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4103, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3359, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(2.6029, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.9844, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2839, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.3884, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.7831, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4318, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5828, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3786, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8133, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3163, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3330, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4883, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3080, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3456, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5458, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.2031, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7352, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3543, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3608, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3179, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4305, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.0462, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3168, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3478, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.3798, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7007, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4311, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(1.4489, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7164, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3499, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.9365, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.7331, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3329, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8750, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5276, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.1875, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.4673, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3950, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3379, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.8957, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5330, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3190, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(5.0890, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5869, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2533, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.2721, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3796, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3148, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5002, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.5424, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.3196, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor(0.1508, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
if not TRAIN_SIGMOID:
    sigmoid_model = GPT2LMHeadModel.from_pretrained("/kaggle/input/gpt2-alignment/" + save_path, return_dict=True).to(device)

# %%
sigmoid_model_texts = generate_texts(sigmoid_model, sequences_for_prompt=int(sequences_for_prompt * 0.2), starting_phrases=["i think that", "basically"]) 
sigmoid_model_rewards = score_texts(reward_model, sigmoid_model_texts)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %%
dpo_trainer.state.log_history
# Out:
# [{'loss': 0.7725,
#   'learning_rate': 8.400000000000001e-06,
#   'rewards/chosen': -0.1890348494052887,
#   'rewards/rejected': -0.3108634650707245,
#   'rewards/accuracies': 0.7171875238418579,
#   'rewards/margins': 0.1218286007642746,
#   'logps/rejected': -194.04702758789062,
#   'logps/chosen': -189.26840209960938,
#   'logits/rejected': -28.451208114624023,
#   'logits/chosen': -27.41998291015625,
#   'epoch': 0.01,
#   'step': 40},
#  {'loss': 0.836,
#   'learning_rate': 6.800000000000001e-06,
#   'rewards/chosen': -0.11405595391988754,
#   'rewards/rejected': -0.296834260225296,
#   'rewards/accuracies': 0.737500011920929,
#   'rewards/margins': 0.1827782690525055,
#   'logps/rejected': -193.00347900390625,
#   'logps/chosen': -188.65390014648438,
#   'logits/rejected': -28.96133804321289,
#   'logits/chosen': -28.458202362060547,
#   'epoch': 0.02,
#   'step': 80},
#  {'loss': 0.6256,
#   'learning_rate': 5.2e-06,
#   'rewards/chosen': -0.1910082995891571,
#   'rewards/rejected': -0.44247207045555115,
#   'rewards/accuracies': 0.7718750238418579,
#   'rewards/margins': 0.25146371126174927,
#   'logps/rejected': -200.04855346679688,
#   'logps/chosen': -189.27593994140625,
#   'logits/rejected': -28.962818145751953,
#   'logits/chosen': -28.45298194885254,
#   'epoch': 0.03,
#   'step': 120},
#  {'loss': 0.7341,
#   'learning_rate': 3.6000000000000003e-06,
#   'rewards/chosen': -0.10948123782873154,
#   'rewards/rejected': -0.3677464723587036,
#   'rewards/accuracies': 0.762499988079071,
#   'rewards/margins': 0.25826525688171387,
#   'logps/rejected': -193.93746948242188,
#   'logps/chosen': -188.01263427734375,
#   'logits/rejected': -30.84171485900879,
#   'logits/chosen': -29.583568572998047,
#   'epoch': 0.04,
#   'step': 160},
#  {'loss': 0.7161,
#   'learning_rate': 2.0000000000000003e-06,
#   'rewards/chosen': -0.1436401903629303,
#   'rewards/rejected': -0.4385661482810974,
#   'rewards/accuracies': 0.8187500238418579,
#   'rewards/margins': 0.2949259877204895,
#   'logps/rejected': -195.62893676757812,
#   'logps/chosen': -192.96714782714844,
#   'logits/rejected': -30.041894912719727,
#   'logits/chosen': -28.56077003479004,
#   'epoch': 0.05,
#   'step': 200},
#  {'loss': 0.617,
#   'learning_rate': 4.0000000000000003e-07,
#   'rewards/chosen': -0.1481238454580307,
#   'rewards/rejected': -0.4331111013889313,
#   'rewards/accuracies': 0.796875,
#   'rewards/margins': 0.284987211227417,
#   'logps/rejected': -196.27178955078125,
#   'logps/chosen': -190.36172485351562,
#   'logits/rejected': -29.552221298217773,
#   'logits/chosen': -29.185495376586914,
#   'epoch': 0.06,
#   'step': 240},
#  {'train_runtime': 213.8486,
#   'train_samples_per_second': 18.705,
#   'train_steps_per_second': 1.169,
#   'total_flos': 0.0,
#   'train_loss': 0.7218484535217286,
#   'epoch': 0.06,
#   'step': 250}]

# %%
plt.figure(figsize=(6, 5))
plt.title("sigmoid model reward distribution")
sns.histplot(flatten(sigmoid_model_rewards))
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: title={'center': 'sigmoid model reward distribution'}, ylabel='Count'>

# %%
np.array(flatten(sigmoid_model_rewards)).mean()
# Out:
# 0.8469222507476807

# %%
sigmoid_model_entropy = token_entropy(flatten(sigmoid_model_texts), tokenizer)

# %%
sigmoid_model_entropy
# Out:
# 5.948066377585916

# %%
init_entropy

# %%
prompts = [
    "one reviewer",
    "Petter Mattei's",
    "Encouraged by the positive comments"
]

# %%
test_texts = generate_texts(sigmoid_model, sequences_for_prompt=int(sequences_for_prompt * 0.2), starting_phrases=prompts) 
test_rewards = score_texts(reward_model, test_texts)
plt.figure(figsize=(6, 5))
plt.title("sigmoid model reward distribution")
sns.histplot(flatten(test_rewards))

# %%
test_texts[1][-10:]
